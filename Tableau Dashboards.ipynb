# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %% [markdown]
# Tableau Public Link:
# https://public.tableau.com/app/profile/vishwesh.singh3849/vizzes
#
# Please visit the Tableau Link to understand in-depth of visualization.

# %% [markdown]
# ### 1. HR-ANALYTICS DASHBOARD

# %%
plt.figure(figsize=(20,10))
hr=plt.imread('Tableau- HR Analytics Dashboard.jpg')
plt.imshow(hr)
plt.show()

# %% [markdown]
# ### 2. Indian Banking Stocks Dashboard

# %%
plt.figure(figsize=(15,10))
bank=plt.imread('Tableau-Indian Bank Dashboard.jpg')
plt.imshow(bank)
plt.show()

# %% [markdown]
# ### 3. Customer Personality Analysis- Dashboard

# %%
plt.figure(figsize=(15,10))
customer=plt.imread('Tableau- Customer Personality Analysis.jpg')
plt.imshow(customer)
plt.show()

# %%
### 4. Balance Sheet Insights Dashboard

# %%
plt.figure(figsize=(15,10))
balance=plt.imread('Tableau-Balance Sheet Insights.jpg')
plt.imshow(balance)
plt.show()

# %% [markdown]
# ### 5. Superstore-Sales Analysis Dashboard

# %%
plt.figure(figsize=(15,10))
sales=plt.imread('Tableau-Sample Superstore-Sales Analysis.jpg')
plt.imshow(sales)
plt.show()
